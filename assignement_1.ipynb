# %%
import pandas as pd

# %% [markdown]
# ***Load csv***

# %%
file_0=pd.read_csv('kiva_loans_part_0.csv')
file_1=pd.read_csv('kiva_loans_part_1.csv')
file_2=pd.read_csv('kiva_loans_part_2.csv')

# %% [markdown]
# **combine files**

# %%
df_loans=pd.concat([file_0,file_1,file_2], ignore_index=True)

# %% [markdown]
# **Numbers of observations**

# %%
df_loans.shape
# Out:
# (671205, 20)

# %%
df_loans.index
# Out:
# RangeIndex(start=0, stop=671205, step=1)

# %% [markdown]
# NaN - no data

# %%
df_loans.describe(include='all')
# Out:
#                   id  funded_amount    loan_amount activity       sector  \
# count   6.712050e+05  671205.000000  671205.000000   671205       671205
# unique           NaN            NaN            NaN      163           15
# top              NaN            NaN            NaN  Farming  Agriculture
# freq             NaN            NaN            NaN    72955       180302
# mean    9.932486e+05     785.995061     842.397107      NaN          NaN
# std     1.966113e+05    1130.398941    1198.660073      NaN          NaN
# min     6.530470e+05       0.000000      25.000000      NaN          NaN
# 25%     8.230720e+05     250.000000     275.000000      NaN          NaN
# 50%     9.927800e+05     450.000000     500.000000      NaN          NaN
# 75%     1.163653e+06     900.000000    1000.000000      NaN          NaN
# max     1.340339e+06  100000.000000  100000.000000      NaN          NaN
#
#                                                       use country_code  \
# ...

# %%
df_loans.info
# Out:
# <bound method DataFrame.info of              id  funded_amount  loan_amount             activity  \
# 0        653051          300.0        300.0  Fruits & Vegetables
# 1        653053          575.0        575.0             Rickshaw
# 2        653068          150.0        150.0       Transportation
# 3        653063          200.0        200.0           Embroidery
# 4        653084          400.0        400.0           Milk Sales
# ...         ...            ...          ...                  ...
# 671200  1340323            0.0         25.0            Livestock
# 671201  1340316           25.0         25.0            Livestock
# 671202  1340334            0.0         25.0                Games
# 671203  1340338            0.0         25.0            Livestock
# 671204  1340339            0.0         25.0            Livestock
#
#                 sector                                                use  \
# 0                 Food            To buy seasonal, fresh fruits to sell.
# ...

# %%
df_loans.columns
# Out:
# Index(['id', 'funded_amount', 'loan_amount', 'activity', 'sector', 'use',
#        'country_code', 'country', 'region', 'currency', 'partner_id',
#        'posted_time', 'disbursed_time', 'funded_time', 'term_in_months',
#        'lender_count', 'tags', 'borrower_genders', 'repayment_interval',
#        'date'],
#       dtype='object')

# %% [markdown]
# ***First 5 observations***

# %%
df_loans.head(5)
# Out:
#        id  funded_amount  loan_amount             activity          sector  \
# 0  653051          300.0        300.0  Fruits & Vegetables            Food
# 1  653053          575.0        575.0             Rickshaw  Transportation
# 2  653068          150.0        150.0       Transportation  Transportation
# 3  653063          200.0        200.0           Embroidery            Arts
# 4  653084          400.0        400.0           Milk Sales            Food
#
#                                                  use country_code   country  \
# 0            To buy seasonal, fresh fruits to sell.            PK  Pakistan
# 1  to repair and maintain the auto rickshaw used ...           PK  Pakistan
# 2  To repair their old cycle-van and buy another ...           IN     India
# 3  to purchase an embroidery machine and a variet...           PK  Pakistan
# 4                           to purchase one buffalo.           PK  Pakistan
#
# ...

# %%
columns=['activity', 'sector', 'country', 'currency']
for x in range(len(list)):
    list[x]=df_loans[columns[x]].unique()
    print('Unique values of', columns[x],':','\n' ,list[x], '\n')
    print('Number of unique', columns[x], 'values:',len(list[x]), '\n')
    print('_______________________________________________________________________________')
# Out:
# Unique values of activity :
#  ['Fruits & Vegetables' 'Rickshaw' 'Transportation' 'Embroidery'
#  'Milk Sales' 'Services' 'Dairy' 'Beauty Salon' 'Manufacturing'
#  'Food Production/Sales' 'Wholesale' 'General Store' 'Clothing Sales'
#  'Poultry' 'Tailoring' 'Sewing' 'Bakery' 'Restaurant' 'Food Stall'
#  'Farming' 'Construction Supplies' 'Personal Products Sales'
#  'Home Products Sales' 'Natural Medicines' 'Fish Selling'
#  'Education provider' 'Shoe Sales' 'Machinery Rental' 'Butcher Shop'
#  'Pigs' 'Personal Expenses' 'Food Market' 'Cosmetics Sales'
#  'Personal Housing Expenses' 'Retail' 'Energy' 'Grocery Store'
#  'Construction' 'Agriculture' 'Motorcycle Transport' 'Charcoal Sales'
#  'Food' 'Pharmacy' 'Fishing' 'Timber Sales' 'Cattle' 'Electronics Repair'
#  'Electronics Sales' 'Vehicle' 'Cafe' 'Blacksmith'
#  'Higher education costs' 'Used Clothing' 'Fuel/Firewood' 'Upholstery'
#  'Catering' 'Animal Sales' 'Cereals' 'Vehicle Repairs' 'Arts'
# ...

# %%
df_loans.sort_values('loan_amount',ascending=False).head(1)
# Out:
#            id  funded_amount  loan_amount     activity       sector  \
# 70499  722883       100000.0     100000.0  Agriculture  Agriculture
#
#                                                      use country_code country  \
# 70499  create more than 300 jobs for women and farmer...           HT   Haiti
#
#           region currency  partner_id                posted_time  \
# 70499  Les Cayes      USD       315.0  2014-06-10 19:25:02+00:00
#
#                   disbursed_time                funded_time  term_in_months  \
# 70499  2014-09-08 07:00:00+00:00  2014-06-19 20:21:04+00:00            75.0
#
#        lender_count                                               tags  \
# 70499          2986  user_favorite, user_favorite, user_favorite, u...
#
#       borrower_genders repayment_interval        date
# 70499           female          irregular  2014-06-10

# %%
df_loans.sort_values('loan_amount',ascending=True).head(1)
# Out:
#              id  funded_amount  loan_amount   activity       sector  \
# 671204  1340339            0.0         25.0  Livestock  Agriculture
#
#                                                       use country_code  \
# 671204  [True, u'to start a turducken farm.'] - this l...           KE
#
#        country region currency  partner_id                posted_time  \
# 671204   Kenya    NaN      KES       138.0  2017-07-26 06:31:46+00:00
#
#                    disbursed_time funded_time  term_in_months  lender_count  \
# 671204  2017-07-25 07:00:00+00:00         NaN            13.0             0
#
#        tags borrower_genders repayment_interval        date
# 671204  NaN           female            monthly  2017-07-26

# %% [markdown]
# 2 rd solution

# %%
min(df_loans['loan_amount'])
# Out:
# 25.0

# %%
max(df_loans['loan_amount'])
# Out:
# 100000.0

# %%
df_loans.sort_values(by='loan_amount',ascending=True).head(10)
# Out:
#              id  funded_amount  loan_amount           activity        sector  \
# 671204  1340339            0.0         25.0          Livestock   Agriculture
# 169099   818230           25.0         25.0            Farming   Agriculture
# 454383  1114340           25.0         25.0            Farming   Agriculture
# 179047   827971           25.0         25.0            Farming   Agriculture
# 169021   818182           25.0         25.0            Farming   Agriculture
# 169011   818259           25.0         25.0  Personal Expenses  Personal Use
# 179353   827972           25.0         25.0            Farming   Agriculture
# 179360   827964           25.0         25.0            Farming   Agriculture
# 179363   827956           25.0         25.0            Farming   Agriculture
# 472707  1132698           25.0         25.0            Farming   Agriculture
#
#                                                       use country_code  \
# ...

# %%
df_loans.sort_values(by='loan_amount',ascending=False).head(10)
# Out:
#              id  funded_amount  loan_amount                   activity  \
# 70499    722883       100000.0     100000.0                Agriculture
# 408465  1055190        50000.0      50000.0               Construction
# 583307  1245201        50000.0      50000.0                Agriculture
# 126839   777718        50000.0      50000.0                Agriculture
# 447374  1107992        50000.0      50000.0                Agriculture
# 210975   859201        50000.0      50000.0                Agriculture
# 53634    706146        50000.0      50000.0  Renewable Energy Products
# 494470  1154951        50000.0      50000.0                Agriculture
# 538248  1198658        50000.0      50000.0                Agriculture
# 660807  1323028        46125.0      50000.0  Renewable Energy Products
#
#               sector                                                use  \
# 70499    Agriculture  create more than 300 jobs for women and farmer...
# ...

# %%
top_activity= df_loans.sort_values(by='loan_amount', ascending=False).head()['activity']
print(top_activity)
# Out:
# 70499      Agriculture
# 408465    Construction
# 583307     Agriculture
# 126839     Agriculture
# 447374     Agriculture
# Name: activity, dtype: object

# %%
loans_by_country=df_loans.groupby('country')['loan_amount'].count()

# %%
sorted_loans_by_country = loans_by_country.sort_values(ascending=False)

# %%
sorted_loans_by_country = loans_by_country.sort_values(ascending=False)
